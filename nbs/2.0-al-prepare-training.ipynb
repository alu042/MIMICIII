# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.structured import *
from fastai.column_data import *
np.set_printoptions(threshold=50, edgeitems=20)
import yaml
from pandas import DataFrame, Series
import shutil

# %%
NB_DIR = %pwd

# %%
RAW_DATA = '/data1/MIMIC-III/RAW/'
INTERIM_DATA = f'{RAW_DATA}/../interim/'
PROCESSED_DATA = f'{RAW_DATA}/../processed/'

# %%
MIMIC3_BENCHMARK_LOCATION = f'{NB_DIR}/../mimic3-benchmarks/'

# %% [markdown]
# # Split train and test
#
# Based on https://github.com/YerevaNN/mimic3-benchmarks/blob/master/scripts/split_train_and_test.py

# %%
testset = set()

# %%
with open(f"{MIMIC3_BENCHMARK_LOCATION}resources/testset.csv", "r") as test_set_file:
    for line in test_set_file:
        x, y = line.split(',')
        if int(y) == 1:
            testset.add(x)

# %%
def copy_to_partition(patients, partition):
    if not os.path.exists(os.path.join(PROCESSED_DATA, partition)):
        os.mkdir(os.path.join(PROCESSED_DATA, partition))
    for patient in patients:
        src = os.path.join(INTERIM_DATA, patient)
        dest = os.path.join(PROCESSED_DATA, partition, patient)
        if not os.path.exists(dest):
            shutil.copytree(src, dest)

# %%
folders = os.listdir(INTERIM_DATA)
folders = list((filter(str.isdigit, folders)))
train_patients = [x for x in folders if not x in testset]
test_patients = [x for x in folders if x in testset]

assert len(set(train_patients) & set(test_patients)) == 0

# %%
folders[:5]
# Out:
# ['27501', '41625', '75430', '7874', '20242']

# %%
copy_to_partition(train_patients, "train")
copy_to_partition(test_patients, "test")

# %% [markdown]
# # In-hospital mortality

# %%
random.seed(49297)

# %%
IHM_DATA = f'{PROCESSED_DATA}/in-hospital-mortality/'

# %%
if not os.path.exists(IHM_DATA):
    os.makedirs(IHM_DATA)

# %%
def process_partition(partition, eps=1e-6, n_hours=48):
    output_dir = os.path.join(IHM_DATA, partition)
    if (not os.path.exists(output_dir)):
        os.mkdir(output_dir)

    xy_pairs = []
    patients = list(filter(str.isdigit, os.listdir(os.path.join(PROCESSED_DATA, partition))))
    for (patient_index, patient) in enumerate(patients):
        patient_folder = os.path.join(PROCESSED_DATA, partition, patient)
        patient_ts_files = list(filter(lambda x: x.find("timeseries") != -1, os.listdir(patient_folder)))

        for ts_filename in patient_ts_files:
            with open(os.path.join(patient_folder, ts_filename)) as tsfile:
                lb_filename = ts_filename.replace("_timeseries", "")
                label_df = pd.read_csv(os.path.join(patient_folder, lb_filename))

                # empty label file
                if (label_df.shape[0] == 0):
                    continue

                mortality = int(label_df.iloc[0]["Mortality"])
                los = 24.0 * label_df.iloc[0]['Length of Stay'] # in hours
                if (pd.isnull(los)):
                    print("\n\t(length of stay is missing)", patient, ts_filename)
                    continue

                if (los < n_hours - eps):
                    continue

                ts_lines = tsfile.readlines()
                header = ts_lines[0]
                ts_lines = ts_lines[1:]
                event_times = [float(line.split(',')[0]) for line in ts_lines]

                ts_lines = [line for (line, t) in zip(ts_lines, event_times)
                                     if (t > -eps and t < n_hours + eps)]
                event_times = [t for t in event_times
                                     if (t > -eps and t < n_hours + eps)]

                # no measurements in ICU
                if (len(ts_lines) == 0):
                    print("\n\t(no events in ICU) ", patient, ts_filename)
                    continue

                output_ts_filename = patient + "_" + ts_filename
                with open(os.path.join(output_dir, output_ts_filename), "w") as outfile:
                    outfile.write(header)
                    for line in ts_lines:
                        outfile.write(line)

                xy_pairs.append((output_ts_filename, mortality))

        if ((patient_index + 1) % 500 == 0):
            print("\rprocessed {} / {} patients".format(patient_index + 1, len(patients)))

    print("\n", len(xy_pairs))
    if partition == "train":
        random.shuffle(xy_pairs)
    if partition == "test":
        xy_pairs = sorted(xy_pairs)

    with open(os.path.join(output_dir, "listfile.csv"), "w") as listfile:
        listfile.write('stay,y_true\n')
        for (x, y) in xy_pairs:
            listfile.write("%s,%d\n" % (x, y))

# %%
process_partition("test")
process_partition("train")
# Out:
# processed 100 / 5070 patients
# processed 200 / 5070 patients
# processed 300 / 5070 patients
# processed 400 / 5070 patients
# processed 500 / 5070 patients
# processed 600 / 5070 patients
# processed 700 / 5070 patients
# processed 800 / 5070 patients
# processed 900 / 5070 patients
# processed 1000 / 5070 patients
# processed 1100 / 5070 patients
# processed 1200 / 5070 patients
# processed 1300 / 5070 patients
# processed 1400 / 5070 patients
# processed 1500 / 5070 patients
# processed 1600 / 5070 patients
# processed 1700 / 5070 patients
# processed 1800 / 5070 patients
# processed 1900 / 5070 patients
# processed 2000 / 5070 patients
# processed 2100 / 5070 patients
# processed 2200 / 5070 patients
# processed 2300 / 5070 patients
# processed 2400 / 5070 patients
# processed 2500 / 5070 patients
# processed 2600 / 5070 patients
# processed 2700 / 5070 patients
# processed 2800 / 5070 patients
# processed 2900 / 5070 patients
# processed 3000 / 5070 patients
# processed 3100 / 5070 patients
# processed 3200 / 5070 patients
# processed 3300 / 5070 patients
# processed 3400 / 5070 patients
# processed 3500 / 5070 patients
# processed 3600 / 5070 patients
# processed 3700 / 5070 patients
# processed 3800 / 5070 patients
# processed 3900 / 5070 patients
# processed 4000 / 5070 patients
# processed 4100 / 5070 patients
# processed 4200 / 5070 patients
# processed 4300 / 5070 patients
# processed 4400 / 5070 patients
# processed 4500 / 5070 patients
# processed 4600 / 5070 patients
# processed 4700 / 5070 patients
# processed 4800 / 5070 patients
# processed 4900 / 5070 patients
# processed 5000 / 5070 patients
#
#  3236
# processed 100 / 28728 patients
# processed 200 / 28728 patients
#
# 	(no events in ICU)  18350 episode1_timeseries.csv
# processed 300 / 28728 patients
# processed 400 / 28728 patients
# processed 500 / 28728 patients
# processed 600 / 28728 patients
# processed 700 / 28728 patients
# processed 800 / 28728 patients
# processed 900 / 28728 patients
# processed 1000 / 28728 patients
# processed 1100 / 28728 patients
# processed 1200 / 28728 patients
# processed 1300 / 28728 patients
# processed 1400 / 28728 patients
# processed 1500 / 28728 patients
# processed 1600 / 28728 patients
# processed 1700 / 28728 patients
# processed 1800 / 28728 patients
# processed 1900 / 28728 patients
# processed 2000 / 28728 patients
# processed 2100 / 28728 patients
# processed 2200 / 28728 patients
# processed 2300 / 28728 patients
# processed 2400 / 28728 patients
# processed 2500 / 28728 patients
#
# 	(length of stay is missing) 10128 episode1_timeseries.csv
# processed 2600 / 28728 patients
# processed 2700 / 28728 patients
# processed 2800 / 28728 patients
# processed 2900 / 28728 patients
# processed 3000 / 28728 patients
# processed 3100 / 28728 patients
# processed 3200 / 28728 patients
# processed 3300 / 28728 patients
# processed 3400 / 28728 patients
# processed 3500 / 28728 patients
# processed 3600 / 28728 patients
# processed 3700 / 28728 patients
# processed 3800 / 28728 patients
# processed 3900 / 28728 patients
# processed 4000 / 28728 patients
# processed 4100 / 28728 patients
# processed 4200 / 28728 patients
# processed 4300 / 28728 patients
# processed 4400 / 28728 patients
# processed 4500 / 28728 patients
# processed 4600 / 28728 patients
# processed 4700 / 28728 patients
# processed 4800 / 28728 patients
# processed 4900 / 28728 patients
# processed 5000 / 28728 patients
# processed 5100 / 28728 patients
# processed 5200 / 28728 patients
# processed 5300 / 28728 patients
# processed 5400 / 28728 patients
# processed 5500 / 28728 patients
# processed 5600 / 28728 patients
# processed 5700 / 28728 patients
# processed 5800 / 28728 patients
# processed 5900 / 28728 patients
# processed 6000 / 28728 patients
# processed 6100 / 28728 patients
# processed 6200 / 28728 patients
# processed 6300 / 28728 patients
# processed 6400 / 28728 patients
# processed 6500 / 28728 patients
# processed 6600 / 28728 patients
# processed 6700 / 28728 patients
# processed 6800 / 28728 patients
# processed 6900 / 28728 patients
# processed 7000 / 28728 patients
# processed 7100 / 28728 patients
# processed 7200 / 28728 patients
# processed 7300 / 28728 patients
# processed 7400 / 28728 patients
# processed 7500 / 28728 patients
# processed 7600 / 28728 patients
# processed 7700 / 28728 patients
# processed 7800 / 28728 patients
# processed 7900 / 28728 patients
# processed 8000 / 28728 patients
# processed 8100 / 28728 patients
# processed 8200 / 28728 patients
# processed 8300 / 28728 patients
#
# 	(no events in ICU)  14469 episode1_timeseries.csv
# processed 8400 / 28728 patients
# processed 8500 / 28728 patients
# processed 8600 / 28728 patients
# processed 8700 / 28728 patients
# processed 8800 / 28728 patients
# processed 8900 / 28728 patients
# processed 9000 / 28728 patients
# processed 9100 / 28728 patients
# processed 9200 / 28728 patients
# processed 9300 / 28728 patients
# processed 9400 / 28728 patients
# processed 9500 / 28728 patients
#
# 	(no events in ICU)  19097 episode1_timeseries.csv
# processed 9600 / 28728 patients
# processed 9700 / 28728 patients
# processed 9800 / 28728 patients
# processed 9900 / 28728 patients
# processed 10000 / 28728 patients
# processed 10100 / 28728 patients
# processed 10200 / 28728 patients
# processed 10300 / 28728 patients
# processed 10400 / 28728 patients
# processed 10500 / 28728 patients
# processed 10600 / 28728 patients
# processed 10700 / 28728 patients
# processed 10800 / 28728 patients
# processed 10900 / 28728 patients
# processed 11000 / 28728 patients
# processed 11100 / 28728 patients
# processed 11200 / 28728 patients
# processed 11300 / 28728 patients
# processed 11400 / 28728 patients
# processed 11500 / 28728 patients
# processed 11600 / 28728 patients
# processed 11700 / 28728 patients
# processed 11800 / 28728 patients
#
# 	(length of stay is missing) 10168 episode1_timeseries.csv
# processed 11900 / 28728 patients
# processed 12000 / 28728 patients
# processed 12100 / 28728 patients
# processed 12200 / 28728 patients
# processed 12300 / 28728 patients
# processed 12400 / 28728 patients
# processed 12500 / 28728 patients
# processed 12600 / 28728 patients
# processed 12700 / 28728 patients
# processed 12800 / 28728 patients
# processed 12900 / 28728 patients
# processed 13000 / 28728 patients
# processed 13100 / 28728 patients
# processed 13200 / 28728 patients
# processed 13300 / 28728 patients
# processed 13400 / 28728 patients
# processed 13500 / 28728 patients
# processed 13600 / 28728 patients
# processed 13700 / 28728 patients
# processed 13800 / 28728 patients
# processed 13900 / 28728 patients
# processed 14000 / 28728 patients
# processed 14100 / 28728 patients
# processed 14200 / 28728 patients
# processed 14300 / 28728 patients
# processed 14400 / 28728 patients
# processed 14500 / 28728 patients
# processed 14600 / 28728 patients
# processed 14700 / 28728 patients
# processed 14800 / 28728 patients
# processed 14900 / 28728 patients
# processed 15000 / 28728 patients
# processed 15100 / 28728 patients
# processed 15200 / 28728 patients
# processed 15300 / 28728 patients
# processed 15400 / 28728 patients
# processed 15500 / 28728 patients
# processed 15600 / 28728 patients
# processed 15700 / 28728 patients
# processed 15800 / 28728 patients
# processed 15900 / 28728 patients
# processed 16000 / 28728 patients
# processed 16100 / 28728 patients
# processed 16200 / 28728 patients
# processed 16300 / 28728 patients
# processed 16400 / 28728 patients
# processed 16500 / 28728 patients
# processed 16600 / 28728 patients
# processed 16700 / 28728 patients
# processed 16800 / 28728 patients
#
# 	(no events in ICU)  19872 episode1_timeseries.csv
# processed 16900 / 28728 patients
# processed 17000 / 28728 patients
# processed 17100 / 28728 patients
# processed 17200 / 28728 patients
# processed 17300 / 28728 patients
# processed 17400 / 28728 patients
# processed 17500 / 28728 patients
# processed 17600 / 28728 patients
# processed 17700 / 28728 patients
# processed 17800 / 28728 patients
# processed 17900 / 28728 patients
# processed 18000 / 28728 patients
# processed 18100 / 28728 patients
# processed 18200 / 28728 patients
# processed 18300 / 28728 patients
# processed 18400 / 28728 patients
# processed 18500 / 28728 patients
# processed 18600 / 28728 patients
# processed 18700 / 28728 patients
# processed 18800 / 28728 patients
# processed 18900 / 28728 patients
# processed 19000 / 28728 patients
# processed 19100 / 28728 patients
#
# 	(length of stay is missing) 499 episode1_timeseries.csv
# processed 19200 / 28728 patients
# processed 19300 / 28728 patients
# processed 19400 / 28728 patients
# processed 19500 / 28728 patients
# processed 19600 / 28728 patients
# processed 19700 / 28728 patients
# processed 19800 / 28728 patients
# processed 19900 / 28728 patients
# processed 20000 / 28728 patients
# processed 20100 / 28728 patients
# processed 20200 / 28728 patients
# processed 20300 / 28728 patients
# processed 20400 / 28728 patients
# processed 20500 / 28728 patients
# processed 20600 / 28728 patients
# processed 20700 / 28728 patients
# processed 20800 / 28728 patients
# processed 20900 / 28728 patients
# processed 21000 / 28728 patients
# processed 21100 / 28728 patients
# processed 21200 / 28728 patients
# processed 21300 / 28728 patients
# processed 21400 / 28728 patients
# processed 21500 / 28728 patients
# processed 21600 / 28728 patients
# processed 21700 / 28728 patients
# processed 21800 / 28728 patients
# processed 21900 / 28728 patients
# processed 22000 / 28728 patients
# processed 22100 / 28728 patients
# processed 22200 / 28728 patients
# processed 22300 / 28728 patients
# processed 22400 / 28728 patients
# processed 22500 / 28728 patients
# processed 22600 / 28728 patients
# processed 22700 / 28728 patients
# processed 22800 / 28728 patients
# processed 22900 / 28728 patients
# processed 23000 / 28728 patients
# processed 23100 / 28728 patients
# processed 23200 / 28728 patients
# processed 23300 / 28728 patients
# processed 23400 / 28728 patients
# processed 23500 / 28728 patients
# processed 23600 / 28728 patients
# processed 23700 / 28728 patients
# processed 23800 / 28728 patients
# processed 23900 / 28728 patients
# processed 24000 / 28728 patients
# processed 24100 / 28728 patients
# processed 24200 / 28728 patients
# processed 24300 / 28728 patients
# processed 24400 / 28728 patients
# processed 24500 / 28728 patients
# processed 24600 / 28728 patients
# processed 24700 / 28728 patients
# processed 24800 / 28728 patients
# processed 24900 / 28728 patients
# processed 25000 / 28728 patients
# processed 25100 / 28728 patients
# processed 25200 / 28728 patients
# processed 25300 / 28728 patients
# processed 25400 / 28728 patients
# processed 25500 / 28728 patients
# processed 25600 / 28728 patients
# processed 25700 / 28728 patients
# processed 25800 / 28728 patients
# processed 25900 / 28728 patients
# processed 26000 / 28728 patients
# processed 26100 / 28728 patients
# processed 26200 / 28728 patients
# processed 26300 / 28728 patients
# processed 26400 / 28728 patients
# processed 26500 / 28728 patients
# processed 26600 / 28728 patients
# processed 26700 / 28728 patients
# processed 26800 / 28728 patients
# processed 26900 / 28728 patients
# processed 27000 / 28728 patients
# processed 27100 / 28728 patients
# processed 27200 / 28728 patients
# processed 27300 / 28728 patients
# processed 27400 / 28728 patients
# processed 27500 / 28728 patients
# processed 27600 / 28728 patients
# processed 27700 / 28728 patients
# processed 27800 / 28728 patients
# processed 27900 / 28728 patients
# processed 28000 / 28728 patients
# processed 28100 / 28728 patients
# processed 28200 / 28728 patients
#
# 	(no events in ICU)  14219 episode1_timeseries.csv
# processed 28300 / 28728 patients
# processed 28400 / 28728 patients
# processed 28500 / 28728 patients
# processed 28600 / 28728 patients
# processed 28700 / 28728 patients
#
#  17903
